# %%
sudo add-apt-repository -y ppa:ubuntugis/ppa
# Out:
# Get:1 http://dl.google.com/linux/chrome/deb stable InRelease [1,825 B]
# Get:2 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:3 http://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:4 http://archive.ubuntu.com/ubuntu focal InRelease [265 kB]
# Get:5 http://ppa.launchpad.net/jonathonf/vim/ubuntu focal InRelease [18.0 kB]
# Err:1 http://dl.google.com/linux/chrome/deb stable InRelease
#   The following signatures couldn't be verified because the public key is not available: NO_PUBKEY 4EB27DB2A3B88B8B
# Get:6 https://deb.nodesource.com/node_12.x focal InRelease [4,583 B]
# Get:7 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease [23.8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:9 http://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ Packages [77.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:11 http://ppa.launchpad.net/jonathonf/vim/ubuntu focal/main amd64 Packages [4,452 B]
# Get:12 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,047 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/multiverse amd64 Packages [177 kB]
# Get:14 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 Packages [63.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/restricted amd64 Packages [33.4 kB]
# Get:16 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,675 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/universe amd64 Packages [11.3 MB]
# Get:18 https://deb.nodesource.com/node_12.x focal/main amd64 Packages [774 B]
# Get:19 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [28.5 kB]
# Get:20 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [2,203 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 Packages [1,275 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,342 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [31.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,341 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,157 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [28.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [55.2 kB]
# Reading package lists... Done
# W: GPG error: http://dl.google.com/linux/chrome/deb stable InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY 4EB27DB2A3B88B8B
# E: The repository 'http://dl.google.com/linux/chrome/deb stable InRelease' is not signed.
# N: Updating from such a repository can't be done securely, and is therefore disabled by default.
# N: See apt-secure(8) manpage for repository creation and user configuration details.
# : 100

# %%
sudo apt-get update
# Out:
# Hit:1 http://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Get:2 http://dl.google.com/linux/chrome/deb stable InRelease [1,825 B]
# Hit:3 http://ppa.launchpad.net/jonathonf/vim/ubuntu focal InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:5 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:6 https://deb.nodesource.com/node_12.x focal InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:8 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Err:2 http://dl.google.com/linux/chrome/deb stable InRelease
#   The following signatures couldn't be verified because the public key is not available: NO_PUBKEY 4EB27DB2A3B88B8B
# Reading package lists... Done
# W: GPG error: http://dl.google.com/linux/chrome/deb stable InRelease: The following signatures couldn't be verified because the public key is not available: NO_PUBKEY 4EB27DB2A3B88B8B
# E: The repository 'http://dl.google.com/linux/chrome/deb stable InRelease' is not signed.
# N: Updating from such a repository can't be done securely, and is therefore disabled by default.
# N: See apt-secure(8) manpage for repository creation and user configuration details.
# : 100

# %%
sudo apt-get install -y gdal-bin
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   gdal-data libde265-0 libdeflate0 libgdal29 libgeotiff-dev libgeotiff5
#   libheif1 libproj19 libx265-179 proj-bin proj-data python3-gdal python3-numpy
# Suggested packages:
#   libgdal-grass libgeotiff-epsg geotiff-bin python-numpy-doc python3-pytest
#   python3-numpy-dbg
# The following NEW packages will be installed:
#   gdal-bin libde265-0 libdeflate0 libgdal29 libheif1 libproj19 libx265-179
#   proj-bin python3-gdal python3-numpy
# The following packages will be upgraded:
#   gdal-data libgeotiff-dev libgeotiff5 proj-data
# 4 upgraded, 10 newly installed, 0 to remove and 350 not upgraded.
# Need to get 22.8 MB of archives.
# After this operation, 68.4 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 gdal-data all 3.3.2+dfsg-2~focal2 [473 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-numpy amd64 1:1.17.4-5ubuntu3.1 [2,724 kB]
# Get:3 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 libgeotiff-dev amd64 1.7.0-2~focal0 [99.4 kB]
# Get:4 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 proj-data all 7.2.1-1~focal0 [7,919 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdeflate0 amd64 1.5-3 [55.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/universe amd64 libde265-0 amd64 1.0.4-1build1 [239 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libx265-179 amd64 3.2.1-1build1 [1,060 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 libheif1 amd64 1.6.1-1build1 [164 kB]
# Get:9 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 libproj19 amd64 7.2.1-1~focal0 [1,103 kB]
# Get:10 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 libgeotiff5 amd64 1.7.0-2~focal0 [70.4 kB]
# Get:11 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 libgdal29 amd64 3.3.2+dfsg-2~focal2 [7,183 kB]
# Get:12 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 python3-gdal amd64 3.3.2+dfsg-2~focal2 [1,026 kB]
# Get:13 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 gdal-bin amd64 3.3.2+dfsg-2~focal2 [511 kB]
# Get:14 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 proj-bin amd64 7.2.1-1~focal0 [170 kB]
# Fetched 22.8 MB in 16s (1,384 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package python3-numpy.
# (Reading database ... 120909 files and directories currently installed.)
# Preparing to unpack .../00-python3-numpy_1%3a1.17.4-5ubuntu3.1_amd64.deb ...
# Unpacking python3-numpy (1:1.17.4-5ubuntu3.1) ...
# Preparing to unpack .../01-gdal-data_3.3.2+dfsg-2~focal2_all.deb ...
# Unpacking gdal-data (3.3.2+dfsg-2~focal2) over (3.0.4+dfsg-1build3) ...
# Selecting previously unselected package libdeflate0.
# Preparing to unpack .../02-libdeflate0_1.5-3_amd64.deb ...
# Unpacking libdeflate0 (1.5-3) ...
# Preparing to unpack .../03-libgeotiff-dev_1.7.0-2~focal0_amd64.deb ...
# Unpacking libgeotiff-dev:amd64 (1.7.0-2~focal0) over (1.5.1-2) ...
# Preparing to unpack .../04-proj-data_7.2.1-1~focal0_all.deb ...
# Unpacking proj-data (7.2.1-1~focal0) over (6.3.1-1) ...
# Selecting previously unselected package libproj19:amd64.
# Preparing to unpack .../05-libproj19_7.2.1-1~focal0_amd64.deb ...
# Unpacking libproj19:amd64 (7.2.1-1~focal0) ...
# Preparing to unpack .../06-libgeotiff5_1.7.0-2~focal0_amd64.deb ...
# Unpacking libgeotiff5:amd64 (1.7.0-2~focal0) over (1.5.1-2) ...
# Selecting previously unselected package libde265-0:amd64.
# Preparing to unpack .../07-libde265-0_1.0.4-1build1_amd64.deb ...
# Unpacking libde265-0:amd64 (1.0.4-1build1) ...
# Selecting previously unselected package libx265-179:amd64.
# Preparing to unpack .../08-libx265-179_3.2.1-1build1_amd64.deb ...
# Unpacking libx265-179:amd64 (3.2.1-1build1) ...
# Selecting previously unselected package libheif1:amd64.
# Preparing to unpack .../09-libheif1_1.6.1-1build1_amd64.deb ...
# Unpacking libheif1:amd64 (1.6.1-1build1) ...
# Selecting previously unselected package libgdal29.
# Preparing to unpack .../10-libgdal29_3.3.2+dfsg-2~focal2_amd64.deb ...
# Unpacking libgdal29 (3.3.2+dfsg-2~focal2) ...
# Selecting previously unselected package python3-gdal.
# Preparing to unpack .../11-python3-gdal_3.3.2+dfsg-2~focal2_amd64.deb ...
# Unpacking python3-gdal (3.3.2+dfsg-2~focal2) ...
# Selecting previously unselected package gdal-bin.
# Preparing to unpack .../12-gdal-bin_3.3.2+dfsg-2~focal2_amd64.deb ...
# Unpacking gdal-bin (3.3.2+dfsg-2~focal2) ...
# Selecting previously unselected package proj-bin.
# Preparing to unpack .../13-proj-bin_7.2.1-1~focal0_amd64.deb ...
# Unpacking proj-bin (7.2.1-1~focal0) ...
# Setting up proj-data (7.2.1-1~focal0) ...
# Setting up libx265-179:amd64 (3.2.1-1build1) ...
# Setting up libdeflate0 (1.5-3) ...
# Setting up gdal-data (3.3.2+dfsg-2~focal2) ...
# Setting up python3-numpy (1:1.17.4-5ubuntu3.1) ...
# Setting up libde265-0:amd64 (1.0.4-1build1) ...
# Setting up libproj19:amd64 (7.2.1-1~focal0) ...
# Setting up libheif1:amd64 (1.6.1-1build1) ...
# Setting up proj-bin (7.2.1-1~focal0) ...
# Setting up libgeotiff5:amd64 (1.7.0-2~focal0) ...
# Setting up libgdal29 (3.3.2+dfsg-2~focal2) ...
# Setting up python3-gdal (3.3.2+dfsg-2~focal2) ...
# Setting up libgeotiff-dev:amd64 (1.7.0-2~focal0) ...
# Setting up gdal-bin (3.3.2+dfsg-2~focal2) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.2) ...

# %%
sudo apt-get install -y libgdal-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libdap-dev libdap25 libdapclient6v5 libdapserver7v5 libepsilon-dev
#   libepsilon1 libgdal26
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libdeflate-dev libheif-dev
# The following NEW packages will be installed:
#   libdeflate-dev libheif-dev
# The following packages will be upgraded:
#   libgdal-dev
# 1 upgraded, 2 newly installed, 0 to remove and 349 not upgraded.
# Need to get 9,487 kB of archives.
# After this operation, 6,965 kB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 libgdal-dev amd64 3.3.2+dfsg-2~focal2 [9,420 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdeflate-dev amd64 1.5-3 [45.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libheif-dev amd64 1.6.1-1build1 [22.0 kB]
# Fetched 9,487 kB in 5s (1,952 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package libdeflate-dev:amd64.
# (Reading database ... 121757 files and directories currently installed.)
# Preparing to unpack .../libdeflate-dev_1.5-3_amd64.deb ...
# Unpacking libdeflate-dev:amd64 (1.5-3) ...
# Selecting previously unselected package libheif-dev:amd64.
# Preparing to unpack .../libheif-dev_1.6.1-1build1_amd64.deb ...
# Unpacking libheif-dev:amd64 (1.6.1-1build1) ...
# Preparing to unpack .../libgdal-dev_3.3.2+dfsg-2~focal2_amd64.deb ...
# Unpacking libgdal-dev (3.3.2+dfsg-2~focal2) over (3.0.4+dfsg-1build3) ...
# Setting up libheif-dev:amd64 (1.6.1-1build1) ...
# Setting up libdeflate-dev:amd64 (1.5-3) ...
# Setting up libgdal-dev (3.3.2+dfsg-2~focal2) ...

# %%
export CPLUS_INCLUDE_PATH=/usr/include/gdal

# %%
export C_INCLUDE_PATH=/usr/include/gdal

# %%
sudo apt-get install -y python3-pip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libdap-dev libdap25 libdapclient6v5 libdapserver7v5 libepsilon-dev
#   libepsilon1 libgdal26
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   python-pip-whl python3-virtualenv
# The following packages will be upgraded:
#   python-pip-whl python3-pip python3-virtualenv
# 3 upgraded, 0 newly installed, 0 to remove and 346 not upgraded.
# Need to get 2,098 kB of archives.
# After this operation, 10.2 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-virtualenv all 20.0.17-1ubuntu0.4 [62.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.8 [231 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.8 [1,805 kB]
# Fetched 2,098 kB in 2s (891 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# (Reading database ... 121776 files and directories currently installed.)
# Preparing to unpack .../python3-virtualenv_20.0.17-1ubuntu0.4_all.deb ...
# Unpacking python3-virtualenv (20.0.17-1ubuntu0.4) over (20.0.17-1) ...
# Preparing to unpack .../python3-pip_20.0.2-5ubuntu1.8_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.8) over (20.0.2-5ubuntu1.1) ...
# Preparing to unpack .../python-pip-whl_20.0.2-5ubuntu1.8_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.8) over (20.0.2-5ubuntu1.1) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.8) ...
# Setting up python3-virtualenv (20.0.17-1ubuntu0.4) ...
# Setting up python3-pip (20.0.2-5ubuntu1.8) ...

# %%
pip install GDAL
# Out:
# Requirement already satisfied: GDAL in /usr/lib/python3/dist-packages (3.3.2)
